# %%
import cv2
import matplotlib.pyplot as plt
import os
import traffic_detect as TD
from time import time
cwd = os.getcwd()

img = cv2.imread('../Image/right1.png')

start = time()
sign_image, _ = TD.detect_sign(img)
end = time()
plt.imshow(sign_image)
print(end-start)
#0.0207920074463
# Out:
# 0.0190601348877
